# %%
Class and Objects

# %%
Class :
    Data members/attributes/variables 
    Methods 
    
Objects

# %%
Paytm
Class :
    contact
    email 
    kyc 
    
    recharge 
    book_tickets 
    bill 
    wallet 
    
user1 
user2

# %%
User 
    user_name    
    email
    password
    
    name
    contact 
    
    login 
    logout 
    
    add_contact
    add_name 
    update_name 
    update_email 
    change_password 
    change_contact

# %%
class User:
    pass

user1 = User()
print(user1)
# Out:
# <__main__.User object at 0x0000022B9DF387B8>

# %%
PEP

# %%
Instance Variable : Every object will have its own copy of that variable

# %%
class User:
    def __init__(self,username,email,password):
        
        self.user_name = username
        self.email = email
        self.password = password
        

user1 = User("abc@123","abc@gmail.com","password@123")
# User(user1,"abc@123","abc@gmail.com","password@123")

user2 = User("pqr@123","pqr@gmail.com","password@123")

# %%
class User:
    
    def signup(self,username,email,password):
        self.user_name = username
        self.email = email
        password = password
        print(password)
    
user1 = User()
user2 = User()
user1.signup("abc@123","abc@gmail.com","password@123")
user2.signup("pqr@123","pqr@gmail.com","password@123")
# User(user1,"abc@123","abc@gmail.com","password@123")
print(user1.user_name,user1.email,user1.password)
print(user2.user_name,user2.email)
# Out:
# password@123
# password@123
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-f17e7704cbde> in <module>()
#      12 user2.signup("pqr@123","pqr@gmail.com","password@123")
#      13 # User(user1,"abc@123","abc@gmail.com","password@123")
# ---> 14 print(user1.user_name,user1.email,user1.password)
#      15 print(user2.user_name,user2.email)
#      16
#
# AttributeError: 'User' object has no attribute 'password'

# %%
*a
**k

# %%
print(user1.user_name,user1.email)
print(user2.user_name,user2.email)
# Out:
# abc@123 abc@gmail.com
# pqr@123 pqr@gmail.com

# %%
class User:
    pass

user1 = User()
print(user1)
# Out:
# <__main__.User object at 0x0000022B9DF4CE80>

# %%
class User:
    def __init__(self,username,email,password):
        
        self.user_name = username
        self.email = email
        self.password = password
        
    def login(self,username,password):
        if self.user_name == username and self.password == password:
            return True
        else:
            return False
        
    def add_name(self,name):
        self.name = name
        
    def change_password(self,new_password):
        self.password = new_password
        
        

user1 = User("abc@123","abc@gmail.com","password@123")
# User(user1,"abc@123","abc@gmail.com","password@123")

user2 = User("pqr@123","pqr@gmail.com","password@123")

print(user2.login("pqr@123","password@123"))
# User.login(user1,"abc@123","password@123")

user1.add_name("ABC")
user2.add_name("PQR")
print(user1.name)
print(user2.name)
print(user1.password)
user1.change_password("abc@123")
print(user1.password)
# Out:
# True
# ABC
# PQR
# password@123
# abc@123

# %%
print(user1.__dict__)
print(user2.__dict__)
# Out:
# {'user_name': 'abc@123', 'email': 'abc@gmail.com', 'password': 'password@123', 'name': 'ABC'}
# {'user_name': 'pqr@123', 'email': 'pqr@gmail.com', 'password': 'password@123', 'name': 'PQR'}

# %%
class User:
    def __init__(self,username,email,password):
        
        self.user_name = username
        self.email = email
        self.password = password
        
    def login(self,username,password):
        if self.user_name == username and self.password == password:
            return True
        else:
            return False
        
    def add_name(self,name):
        self.name = name
        
    def change_password(self,new_password):
        self.password = new_password
        
    def __str__(self):
        return "{} {}".format(self.user_name,self.email)
    
    def get_details(self):
        return "{} {} {}".format(self.user_name,self.email,self.name)
        

user1 = User("abc@123","abc@gmail.com","password@123")
# User(user1,"abc@123","abc@gmail.com","password@123")

user2 = User("pqr@123","pqr@gmail.com","password@123")
user3 = User("xyz@123","xyz@gmail.com","password@123")
user4 = User("rst@123","rst@gmail.com","password@123")

user1.add_name("ABC")
user2.add_name("PQR")
user3.add_name("RST")
user4.add_name("XYZ")

users = [user1,user2,user3,user4]
for user in users:
    print(user.get_details())
# print(user1)
# Out:
# abc@123 abc@gmail.com ABC
# pqr@123 pqr@gmail.com PQR
# xyz@123 xyz@gmail.com RST
# rst@123 rst@gmail.com XYZ

# %%
Student 
     name 
     roll_no 
     
    
     add_marks marks = []
     cal_result()
    
    
     All students who failed 
     Topper of the class name,rollno, marks , percernatge

# %%
class Student:
    def __init__(self,roll_no,name):
        self.roll_no = roll_no
        self.name = name
        
    def add_marks(self,marks):
        self.marks = marks
        
    def cal_result(self):
        self.per = sum(self.marks.values())/500 * 100
        if self.per >= 40:
            self.result = "Pass"
        else:
            self.result = "Fail"
            
    def get_details(self):
        return "{} {} {} {}".format(str(self.roll_no),self.name,round(self.per,2),self.result)
    
    
stud1 = Student(1,"ABC")
stud2 = Student(2,"PQR")
stud3 = Student(3,"RST")
stud4 = Student(4,"XYZ")
stud5 = Student(5,"PPP")
stud6 = Student(6,"TTT")

stud1.add_marks({"eng":78,"maths":88,"his":88,"sci":88,"geo":99})
stud2.add_marks({"eng":80,"maths":77,"his":89,"sci":70,"geo":40})
stud3.add_marks({"eng":50,"maths":33,"his":30,"sci":30,"geo":30})
stud4.add_marks({"eng":30,"maths":44,"his":35,"sci":56,"geo":30})
stud5.add_marks({"eng":20,"maths":20,"his":20,"sci":44,"geo":20})
stud6.add_marks({"eng":35,"maths":66,"his":89,"sci":76,"geo":99})

students = [stud1,stud2,stud3,stud4,stud5,stud6]
for student in students:
    student.cal_result()
    

#Failed Students
for student in students:
    if student.result == "Fail":
        print(student.get_details())
        
student_per = [(student,student.per) for student in students if student.result == "Pass"]
print(student_per)
topper = max(student_per,key = lambda t : t[1])
print(topper)
print("Topper of the class is",topper[0].get_details())
# Out:
# 3 RST 34.6 Fail
# 4 XYZ 39.0 Fail
# 5 PPP 24.8 Fail
# [(<__main__.Student object at 0x0000022B9E04ACC0>, 88.2), (<__main__.Student object at 0x0000022B9E04AC50>, 71.2), (<__main__.Student object at 0x0000022B9E04AD68>, 73.0)]
# (<__main__.Student object at 0x0000022B9E04ACC0>, 88.2)
# Topper of the class is 1 ABC 88.2 Pass

# %%
All per [88,89,90,100] =100

# %%
help(max)
# Out:
# Help on built-in function max in module builtins:
#
# max(...)
#     max(iterable, *[, default=obj, key=func]) -> value
#     max(arg1, arg2, *args, *[, key=func]) -> value
#
#     With a single iterable argument, return its biggest item. The
#     default keyword-only argument specifies an object to return if
#     the provided iterable is empty.
#     With two or more arguments, return the largest argument.

# %%
class class_name
    def __init__(self,val1,val2):
        self.var_name = val1
        
    def __str__(self):
        return str

obj_name = class_name("ABC","PQR")
print(obj_name)

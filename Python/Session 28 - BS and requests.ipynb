# %%
https://www.flipkart.com/ => req to flipkart server => response (HTML)

# %%
HTML => Data
CSS => 
JS

# %%
requests 
beautiful soup

# %%
pip install requests 
pip install BeautifulSoup4

# %%
# !pip install requests

# %%
import requests
from bs4 import BeautifulSoup

# %%
<html>
    <body>
        <div>
            <p>Add some text</p>
            <a href="www.google.com">Click Here</a>
        </div>
        <img src=".jpg">
    </body>
</html>

# %%
tags 
attributes 
Text

# %%
id 
class 
name

# %%
response = requests.get("https://www.flipkart.com/search?q=mobiles&as=on&as-show=on&otracker=AS_Query_TrendingAutoSuggest_0_0_na_na_na&otracker1=AS_Query_TrendingAutoSuggest_0_0_na_na_na&as-pos=0&as-type=HISTORY&suggestionId=mobiles&requestId=e845a4bd-aebb-48da-b9fe-a055fe763b72")
print(response)
# Out:
# <Response [200]>

# %%
print(response.status_code)
# Out:
# 200

# %%
print(response.content)
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\t<link href="https://rukminim1.flixcart.com" rel="dns-prefetch" />\n\t<link href="https://img1a.flixcart.com" rel="dns-prefetch" />\n\t<link rel="stylesheet" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.82a2ce.css" />\n\n\t<link rel="preload" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" as="image">\n\n\t<meta http-equiv="Content-type" content="text/html; charset=utf-8"/>\n\t<meta http-equiv="X-UA-Compatible" content="IE=Edge" />\n\t<meta property="fb:page_id" content="102988293558"/>\n\t<meta property="fb:admins" content="658873552,624500995,100000233612389"/>\n\t<meta name="robots" content="noodp" />\n\n\t<link rel=\'shortcut icon\' href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" />\n\n\t<link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/>\n\n\t<meta property="og:type" content="website"/>\n\t<meta name="og_site_name" pr
# ...

# %%
GET
POST 
PUT 
DELETE

# %%
2XX => Success code 
200 => OK
201 => Created 

4XX => Client Side Error 
401
403
404 => Page not found 

5XX => Server Side error 
500 => Internal server error

# %%
soup = BeautifulSoup(response.content,"html.parser")

# %%
                              soup
                              HTML
    Head                                              Body
                                             div                 img
                                     a              p

# %%
find("div")
find_all("div")

# %%
title = soup.find("div", attrs={"class":"_3wU53n"})
print(title.text)
# Out:
# Redmi 8 (Onyx Black, 64 GB)

# %%
titles = soup.find_all("div", attrs={"class":"_3wU53n"})
for title in titles:
    print(title.text)
# Out:
# Redmi 8 (Onyx Black, 64 GB)
# Realme 3i (Diamond Blue, 32 GB)
# Realme 3i (Diamond Red, 64 GB)
# Realme 3i (Diamond Black, 64 GB)
# Realme 3i (Diamond Black, 32 GB)
# Realme 3i (Diamond Blue, 64 GB)
# Redmi 8A (Ocean Blue, 32 GB)
# Redmi Note 7 Pro (Neptune Blue, 64 GB)
# Redmi Note 7S (Sapphire Blue, 64 GB)
# Realme 5 Pro (Sparkling Blue, 128 GB)
# Realme 5 Pro (Sparkling Blue, 64 GB)
# Realme 5 Pro (Crystal Green, 64 GB)
# Realme 5 Pro (Sparkling Blue, 64 GB)
# I Kall k16 new mobile
# Redmi 7A (Matte Blue, 32 GB)
# Redmi Note 7 Pro (Space Black, 64 GB)
# Realme 5 Pro (Crystal Green, 128 GB)
# Redmi 8A (Midnight Black, 32 GB)
# Realme 5 Pro (Crystal Green, 64 GB)
# I Kall K8 (Gold, 16 GB)
# Realme 5s (Crystal Blue, 128 GB)
# Realme C2 (Diamond Sapphire, 32 GB)
# Realme C2 (Diamond Black, 32 GB)
# I Kall K-2 (Black, 8 GB)

# %%
card = soup.find("div",attrs={"class":"_1UoZlX"})
title = card.find("div", attrs={"class":"_3wU53n"})
price = card.find("div",attrs={"class":"_2rQ-NK"})
rating = card.find("div",attrs={"class":"hGSR34"})
print("{} {} {}".format(title.text,price.text,rating.text))
# Out:
# Redmi 8 (Onyx Black, 64 GB) ₹7,999 4.5

# %%
cards = soup.find_all("div",attrs={"class":"_1UoZlX"})
for card in cards:
    title = card.find("div", attrs={"class":"_3wU53n"})
    price = card.find("div",attrs={"class":"_2rQ-NK"})
    rating = card.find("div",attrs={"class":"hGSR34"})
    print("{} {} {}".format(title.text,price.text,rating.text))
# Out:
# Redmi 8 (Onyx Black, 64 GB) ₹7,999 4.5
# Realme 3i (Diamond Blue, 32 GB) ₹7,999 4.4
# Realme 3i (Diamond Black, 64 GB) ₹9,999 4.4
# Realme 3i (Diamond Red, 64 GB) ₹9,999 4.4
# Realme 3i (Diamond Blue, 64 GB) ₹9,999 4.4
# Realme 3i (Diamond Black, 32 GB) ₹7,999 4.4
# Redmi 8A (Ocean Blue, 32 GB) ₹6,999 4.4
# Redmi Note 7S (Sapphire Blue, 64 GB) ₹9,999 4.4
# Realme 5s (Crystal Purple, 128 GB) ₹10,999 4.6
# Redmi Note 7 Pro (Neptune Blue, 64 GB) ₹10,999 4.5
# Realme 5 Pro (Crystal Green, 64 GB) ₹12,999 4.5
# Realme 5 Pro (Sparkling Blue, 128 GB) ₹15,999 4.5
# Realme 5 Pro (Sparkling Blue, 64 GB) ₹12,999 4.5
# I Kall k16 new mobile ₹468 3.7
# Realme 5 Pro (Sparkling Blue, 64 GB) ₹13,999 4.5
# Redmi 7A (Matte Blue, 32 GB) ₹5,499 4.3
# Realme 5s (Crystal Blue, 128 GB) ₹10,999 4.6
# Realme C2 (Diamond Black, 32 GB) ₹5,999 4.4
# Realme C2 (Diamond Sapphire, 32 GB) ₹6,999 4.3
# I Kall K8 NEW (Blue, 16 GB) ₹3,369 3.4
# Realme C2 (Diamond Blue, 32 GB) ₹5,999 4.4
# ...

# %%
HOME_URL = "https://www.flipkart.com"
next_link = soup.find("a",attrs={"class":"_3fVaIS"})
print(HOME_URL+next_link.get("href"))

response2 = requests.get(HOME_URL+next_link.get("href"))
print(response2.status_code)
soup2 = BeautifulSoup(response2.content,"html.parser")
cards = soup2.find_all("div",attrs={"class":"_1UoZlX"})
for card in cards:
    title = card.find("div", attrs={"class":"_3wU53n"})
    price = card.find("div",attrs={"class":"_2rQ-NK"})
    rating = card.find("div",attrs={"class":"hGSR34"})
    print("{} {} {}".format(title.text,price.text,rating.text))
# Out:
# https://www.flipkart.com/search?q=mobiles&as=on&as-show=on&otracker=AS_Query_TrendingAutoSuggest_0_0_na_na_na&otracker1=AS_Query_TrendingAutoSuggest_0_0_na_na_na&as-pos=0&as-type=HISTORY&suggestionId=mobiles&requestId=e845a4bd-aebb-48da-b9fe-a055fe763b72&page=2
# 200
# Apple iPhone 7 (Black, 32 GB) ₹24,999 4.5
# Vivo Z1x (Fusion Blue, 128 GB) ₹14,990 4.5
# Realme XT (Pearl Blue, 64 GB) ₹15,999 4.5
# Infinix Hot 8 (Quetzal Cyan, 64 GB) ₹6,999 4.5
# Infinix Hot 8 (Cosmic Purple, 64 GB) ₹6,999 4.5
# I Kall K4 (Sea Blue, 16 GB) ₹2,999 3.4
# Infinix S5 Lite (Quetzal Cyan, 64 GB) ₹7,999 4.4
# Infinix S5 Lite (Violet, 64 GB) ₹7,999 4.4
# Redmi 8A (Sunset Red, 32 GB) ₹6,499 4.4
# I Kall K700 (Red, 32 GB) ₹5,599 3.3
# Redmi 7A (Matte Gold, 32 GB) ₹5,499 4.3
# Vivo Z1x (Fusion Blue, 64 GB) ₹15,990 4.4
# Realme 5 (Crystal Purple, 128 GB) ₹10,999 4.4
# Realme 5 (Crystal Blue, 32 GB) ₹8,999 4.5
# Redmi Note 7 Pro (Astro Moonlight White, 64 GB) ₹10,999 4.5
# I Kall K3 (Red, 16 GB) ₹4,299 3.4
# ...

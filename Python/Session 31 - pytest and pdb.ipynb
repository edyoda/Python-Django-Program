# %%
Agile

# %%
Requirement Analysis
Design phase 
Development phase
Testing 
Deployment and maintaince

# %%
As 
I want 
so that

# %%
TDD
BDD

# %%
Gap Analysis

# %%
405 page

# %%
story points

# %%
5 features 
5 user stories 

40/50
38/50

# %%
pip install pytest

# %%
code => Py1 func1
           func2
           func3
        py2
Test
    test_py1
          test_func1
          test_func2
          test_func3
    test_py2

# %%
pytest

# %%
assert 10 == 11
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-2-30ca923ee8cb> in <module>()
# ----> 1 assert 10 == 11
#
# AssertionError:

# %%
execute all test and all func : pytest -v 
specific file : pytest -v filename.py
specific func : pytest -v filename.py::func_name
            
Set the marker
@pytest.mark.marker_name

pytest -v -m "marker_name"

# %%
src :
    pkg1
        py_1
        py_2
    
test : 
    test_py1
    test_py2

# %%
import pytest
help(pytest)
# Out:
# Help on module pytest:
#
# NAME
#     pytest - pytest: unit and functional testing with Python.
#
# SUBMODULES
#     collect
#
# CLASSES
#     _pytest.nodes.FSCollector(_pytest.nodes.Collector)
#         _pytest.main.Session
#         _pytest.nodes.File
#             _pytest.python.Module(_pytest.nodes.File, _pytest.python.PyCollector)
#     _pytest.nodes.Node(builtins.object)
#         _pytest.nodes.Collector
#         _pytest.nodes.Item
#             _pytest.python.Function(_pytest.python.FunctionMixin, _pytest.nodes.Item, _pytest.compat.FuncargnamesCompatAttr)
#     _pytest.python.FunctionMixin(_pytest.python.PyobjMixin)
#         _pytest.python.Function(_pytest.python.FunctionMixin, _pytest.nodes.Item, _pytest.compat.FuncargnamesCompatAttr)
#         _pytest.python.Generator(_pytest.python.FunctionMixin, _pytest.python.PyCollector)
#     _pytest.python.PyCollector(_pytest.python.PyobjMixin, _pytest.nodes.Collector)
#         _pytest.python.Class
# ...

# %%
import pdb

# %%
pbd.set_trace()
(pdb)
n : next line 
s : step into func
c : continue the exe till end 
r : execute till return stmt 
ll : long list 
h : help

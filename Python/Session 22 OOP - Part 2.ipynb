# %%
class Class_name:
    def __init__(self):
        self.var_name = val

obj_name = Class_name()

# %%
class User:
    def __init__(self,username,email,password):
        
        self.user_name = username
        self.email = email
        self.password = password
        

user1 = User("abc@123","abc@gmail.com","password@123")
# User(user1,"abc@123","abc@gmail.com","password@123")

user2 = User("pqr@123","pqr@gmail.com","password@123")

# %%
Class variables

# %%
class Student:
    count = 0
    students = []
    
    def __init__(self,roll_no,name):
        self.roll_no = roll_no
        self.name = name
        Student.count+=1
        Student.students.append(self)
        
    def add_marks(self,marks):
        self.marks = marks
        
    def cal_result(self):
        self.per = sum(self.marks.values())/500 * 100
        if self.per >= 40:
            self.result = "Pass"
        else:
            self.result = "Fail"
            
    def get_details(self):
        return "{} {} {} {}".format(str(self.roll_no),self.name,round(self.per,2),self.result)
    
    def __str__(self):
        return "{} {}".format(self.roll_no,self.name)
    
    def __add__(self,obj2):
        return sum(self.marks.values()) + sum(obj2.marks.values()) 
    
    def __sub__(self,obj2):
        return sum(self.marks.values()) - sum(obj2.marks.values())
    
    def __mul__(self,num):
#         print(type(self),type(num))
        return sum(self.marks.values())*num
print(stud1.count)
print(stud1.__dict__)
stud1.count = 100
print(stud1.count)
print(stud1.__dict__)
        
print(Student.count)      
    
stud1 = Student(1,"ABC")
stud2 = Student(2,"PQR")
stud3 = Student(3,"RST")
stud4 = Student(4,"XYZ")
stud5 = Student(5,"PPP")
stud6 = Student(6,"TTT")

print(Student.count)
# print(Student.count)

# print(Student.students)

stud1.add_marks({"eng":78,"maths":88,"his":88,"sci":88,"geo":99})
stud2.add_marks({"eng":80,"maths":77,"his":89,"sci":70,"geo":40})
stud3.add_marks({"eng":50,"maths":33,"his":30,"sci":30,"geo":30})
stud4.add_marks({"eng":30,"maths":44,"his":35,"sci":56,"geo":30})
stud5.add_marks({"eng":20,"maths":20,"his":20,"sci":44,"geo":20})
stud6.add_marks({"eng":35,"maths":66,"his":89,"sci":76,"geo":99})

# print(stud1 * 2)
students = [stud1,stud2,stud3,stud4,stud5,stud6]
for student in Student.students:
    student.cal_result()
    

# #Failed Students
for student in Student.students:
    if student.result == "Fail":
        print(student.get_details())
        
student_per = [(student,student.per) for student in Student.students if student.result == "Pass"]
print(student_per)
topper = max(student_per,key = lambda t : t[1])
# print(topper)
print("Topper of the class is",topper[0].get_details())
# Out:
# 0
# 6
# 6
# {'roll_no': 1, 'name': 'ABC'}
# 100
# {'roll_no': 1, 'name': 'ABC', 'count': 100}
# 3 RST 34.6 Fail
# 4 XYZ 39.0 Fail
# 5 PPP 24.8 Fail
# [(<__main__.Student object at 0x000001F97BC70588>, 88.2), (<__main__.Student object at 0x000001F97BC705C0>, 71.2), (<__main__.Student object at 0x000001F97BC70668>, 73.0)]
# Topper of the class is 1 ABC 88.2 Pass

# %%
Everything in Python is Object

# %%
l1 = [10,20,30]
l2 = [100,200,300]
print(l1 * 2)
# Out:
# [10, 20, 30, 10, 20, 30]

# %%
print(dir(list))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
class list:
    
    def append(self):
        
    def extend(self):

# %%
instance methods => instance variables 
class methods => modify class variable

# %%
class Student:
    count = 0
    students = []
    
    @classmethod
    def incr_count(cls):
        cls.count += 1 
        
    @classmethod
    def add_student(cls,obj):
        cls.students.append(obj)
    
    
    def __init__(self,roll_no,name):
        self.roll_no = roll_no
        self.name = name
        Student.incr_count()
        Student.add_student(self)
  
        
    def add_marks(self,marks):
        self.marks = marks
        
    def cal_result(self):
        self.per = sum(self.marks.values())/500 * 100
        if self.per >= 40:
            self.result = "Pass"
        else:
            self.result = "Fail"
            
    def get_details(self):
        return "{} {} {} {}".format(str(self.roll_no),self.name,round(self.per,2),self.result)
    
    def __str__(self):
        return "{} {}".format(self.roll_no,self.name)
    
    def __add__(self,obj2):
        return sum(self.marks.values()) + sum(obj2.marks.values()) 
    
    def __sub__(self,obj2):
        return sum(self.marks.values()) - sum(obj2.marks.values())
    
    def __mul__(self,num):
#         print(type(self),type(num))
        return sum(self.marks.values())*num
print(stud1.count)
print(stud1.__dict__)
stud1.count = 100
print(stud1.count)
print(stud1.__dict__)
        
print(Student.count)      
    
stud1 = Student(1,"ABC")
stud2 = Student(2,"PQR")
stud3 = Student(3,"RST")
stud4 = Student(4,"XYZ")
stud5 = Student(5,"PPP")
stud6 = Student(6,"TTT")

print(Student.count)
# print(Student.count)

# print(Student.students)

stud1.add_marks({"eng":78,"maths":88,"his":88,"sci":88,"geo":99})
stud2.add_marks({"eng":80,"maths":77,"his":89,"sci":70,"geo":40})
stud3.add_marks({"eng":50,"maths":33,"his":30,"sci":30,"geo":30})
stud4.add_marks({"eng":30,"maths":44,"his":35,"sci":56,"geo":30})
stud5.add_marks({"eng":20,"maths":20,"his":20,"sci":44,"geo":20})
stud6.add_marks({"eng":35,"maths":66,"his":89,"sci":76,"geo":99})

# print(stud1 * 2)
students = [stud1,stud2,stud3,stud4,stud5,stud6]
for student in Student.students:
    student.cal_result()
    

# #Failed Students
for student in Student.students:
    if student.result == "Fail":
        print(student.get_details())
        
student_per = [(student,student.per) for student in Student.students if student.result == "Pass"]
print(student_per)
topper = max(student_per,key = lambda t : t[1])
# print(topper)
print("Topper of the class is",topper[0].get_details())
# Out:
# 100
# {'roll_no': 1, 'name': 'ABC', 'count': 100, 'marks': {'eng': 78, 'maths': 88, 'his': 88, 'sci': 88, 'geo': 99}, 'per': 88.2, 'result': 'Pass'}
# 100
# {'roll_no': 1, 'name': 'ABC', 'count': 100, 'marks': {'eng': 78, 'maths': 88, 'his': 88, 'sci': 88, 'geo': 99}, 'per': 88.2, 'result': 'Pass'}
# 0
# 6
# 3 RST 34.6 Fail
# 4 XYZ 39.0 Fail
# 5 PPP 24.8 Fail
# [(<__main__.Student object at 0x000001F97BC661D0>, 88.2), (<__main__.Student object at 0x000001F97BC66400>, 71.2), (<__main__.Student object at 0x000001F97BC664E0>, 73.0)]
# Topper of the class is 1 ABC 88.2 Pass

# %%
class User:
    def __init__(self,username,email,password):
        
        self.user_name = username
        self.email = email
        self.password = password
        
    def login(self,username,password):
        if self.user_name == username and self.password == password:
            return True
        else:
            return False
        
    def add_name(self,name):
        self.name = name
        
    def change_password(self,new_password):
        self.password = new_password
        
    def __str__(self):
        return "{} {}".format(self.user_name,self.email)
    
    def get_details(self):
        return "{} {} {}".format(self.user_name,self.email,self.name)
        

user1 = User("abc@123","abc@gmail.com","password@123")
# User(user1,"abc@123","abc@gmail.com","password@123")

user2 = User("pqr@123","pqr@gmail.com","password@123")
user3 = User("xyz@123","xyz@gmail.com","password@123")
user4 = User("rst@123","rst@gmail.com","password@123")

user1.add_name("ABC")
user2.add_name("PQR")
user3.add_name("RST")
user4.add_name("XYZ")

users = [user1,user2,user3,user4]
for user in users:
    print(user.get_details())
# print(user1)

# %%
Course 
    c_id
    c_name
    c_description 
    c_duration 
    c_author
    c_price 

Tutorial 
    t_id
    t_title
    t_content 
    t_course 

- All the tutorials of course "Python"
- All the tutorials by Author "ABC"
        - Iterate over all tut
        - for evry tut check the course.author 
        
        
        - Iterate over courses and find out all the courses by author ABC
        - Iterate over tut and check if the course in step 1 

# 1 course multiple tutorials

# %%
class Course:
    courses = []
    def __init__(self,id,title,duration,author,price):
        self.c_id = id
        self.c_title = title
        self.c_duration = duration
        self.c_autor = author
        self.c_price = price
        Course.courses.append(self)
        

class Tutorial:
    tutorials = []
    def __init__(self,id,title,content,course):
        self.t_id = id
        self.t_title = title
        self.t_content = content
        self.course = course
        Tutorial.tutorials.append(self)
        
    def get_details(self):
        return "{} {} {}".format(self.t_id,self.t_title,self.t_content)

course1 = Course(1,"Python","30","ABC",5000)
course2 = Course(2,"Django","50","ABC",10000)
course3 = Course(3,"Machin Learning","70","PQR",20000)

tu1 = Tutorial(101,"Python Datatypes","List,Dict,Set,Tuples",course1)
tu2 = Tutorial(102,"Python Functions","Parameter passing technigues",course1)
tu3 = Tutorial(103,"Django Models","Models and ORM",course2)
tu4 = Tutorial(104,"Numpy","numpy array",course3)
tu5 = Tutorial(105,"Pandas","pandas dataframes",course3)

for course in Course.courses:
    if course.c_title == "Python":
        c_python = course
print(c_python.c_title)

print("Tutorial for course Python")
for tut in Tutorial.tutorials:
    if tut.course == c_python:
        print(tut.get_details())
        
# print(Tutorial.tutorials)

print("\n\nAll tutorials for author ABC")
for tut in Tutorial.tutorials:
    if tut.course.c_autor == "ABC":
        print(tut.get_details())

print("\n\nAll tutorials for author ABC")

c_abc =[course for course in Course.courses if course.c_autor == "ABC"]

for tut in Tutorial.tutorials:
    if tut.course in c_abc:
        print(tut.get_details())
# Out:
# Python
# Tutorial for course Python
# 101 Python Datatypes List,Dict,Set,Tuples
# 102 Python Functions Parameter passing technigues
#
#
# All tutorials for author ABC
# 101 Python Datatypes List,Dict,Set,Tuples
# 102 Python Functions Parameter passing technigues
# 103 Django Models Models and ORM
#
#
# All tutorials for author ABC
# 101 Python Datatypes List,Dict,Set,Tuples
# 102 Python Functions Parameter passing technigues
# 103 Django Models Models and ORM
